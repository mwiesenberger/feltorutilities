# %%
import feltorutilities as fp
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.2e' % x)

# %%
physicals=list()
physicals.append({"name" : "TJK",
    "T_e":10, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 0.6, "n_0" : 0.1, "B_0" : 0.07, "a" : 0.1, "q":2})
physicals.append({"name" : "TJK",
    "T_e":40, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 0.6, "n_0" : 0.1, "B_0" : 0.7, "a" : 0.1, "q":2})
physicals.append({"name" : "ST25",
    "T_e":10, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 0.25, "n_0" : 0.01, "B_0" : 0.1, "a" : 0.125, "q":2})
physicals.append({"name" : "Compass",
    "T_e":50, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 0.56, "n_0" : 0.5, "B_0" : 0.4, "a" : 0.16, "q":2})
physicals.append({"name" : "Compass",
    "T_e":100, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 0.56, "n_0" : 1, "B_0" : 0.8, "a" : 0.16, "q":2})
physicals.append({"name" : "AUG",
    "T_e":450, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 1.65, "n_0" : 2.5, "B_0" : 2, "a" : 0.5, "q":5})
physicals.append({"name" : "AUG",
    "T_e":300, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 1.65, "n_0" : 2.5, "B_0" : 2, "a" : 0.5, "q":2})
physicals.append({"name" : "TCV-ENRX",
    "T_e":41.3, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 0.906, "n_0" : 0.2, "B_0" : 0.929, "a" : 0.25, "q":2})
physicals.append({"name" : "TCV",
    "T_e":41.3, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 0.906, "n_0" : 1, "B_0" : 1.4, "a" : 0.25, "q":2})
physicals.append({"name" : "XGC1",
    "T_e":41.3, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 1.67, "n_0" : 0.07, "B_0" : 0.5, "a" : 0.67, "q":2})
physicals.append({"name" : "Torpex-ENRX",
    "T_e":2.21, "T_i": 0, "m_i" : fp.proton_mass,
    "R": 1, "n_0" : 0.001, "B_0" : 0.076, "a" : 0.2, "q":5})


##################################################
physicals.append({"name" : "Compass",
    "T_e":1.27, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 0.545, "n_0" : 0.15, "B_0" : 0.066, "a":0.175, "q":2})
physicals.append({"name" : "Compass",
    "T_e":25, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 0.545, "n_0" : 0.15, "B_0" : 0.8, "a":0.175, "q":2})
physicals.append({"name" : "Compass",
    "T_e":50, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 0.545, "n_0" : 0.15, "B_0" : 0.8, "a":0.175, "q":2})
physicals.append({"name" : "Compass",
    "T_e":100, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 0.545, "n_0" : 0.15, "B_0" : 0.6, "a":0.175, "q":2})
physicals.append({"name" : "Compass",
    "T_e":200, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 0.545, "n_0" : 0.15, "B_0" : 0.8, "a":0.175, "q":2})
physicals.append({"name" : "Compass",
    "T_e":2.86, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 0.545, "n_0" : 0.17, "B_0" : 0.099, "a":0.175, "q":2})
physicals.append({"name" : "Compass",
    "T_e":1.56, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 0.545, "n_0" : 0.17, "B_0" : 0.073, "a":0.175, "q":2})
physicals.append({"name" : "Compass",
    "T_e":0.16, "T_i": 0, "m_i" : fp.deuteron_mass,
    "R": 0.545, "n_0" : 0.002, "B_0" : 0.026, "a":0.175, "q":2})

# %%
fp.quantities()
# Out:
# dict_keys(['rho_s', 'omega_0_inv', 'c_s', 'Phi_0', 'Psip_0', 'lambda_D', 'mu', 'tau', 'beta', 'resistivity', 'R_0', 'epsilon_D', 'viscosity_e', 'viscosity_i', 'inverseaspectratio', 'aspectratio', 'a_0', 'lparallel', 'lparallel_rhos', 'Myra', 'Knudsen', 'pref', 'nu_perp', 'GAM_inv', 'paraview_scale', 'GBS_timescale', 'GBS_resistivity', 'CFL_diff'])

# %%
data=list()

columns=[*physicals[0].keys(), *fp.quantities() ]
for physical in physicals:
    physical["scaleR"] = 1.3
    physical["Nz"] = 32
    data.append( fp.parameters2quantities( physical, columns))
df = pd.DataFrame( data, columns=columns)

# %%
show = ["name", "R_0", "a_0", "beta", "resistivity", "T_e", "n_0", "B_0", "CFL_diff", "epsilon_D"]
df_dir = df[show]
df_dir = df_dir.loc [ df_dir["name"]=="Compass"]
df_dir
# Out:
#        name      R_0      a_0     beta  resistivity      T_e      n_0  \
# 3   Compass 2.19e+02 6.85e+01 3.15e-04     2.98e-06 5.00e+01 5.00e-01
# 4   Compass 3.10e+02 9.69e+01 3.15e-04     1.05e-06 1.00e+02 1.00e+00
# 11  Compass 2.21e+02 7.09e+01 8.80e-05     1.34e-03 1.27e+00 1.50e-01
# 12  Compass 6.04e+02 1.94e+02 1.18e-05     1.26e-06 2.50e+01 1.50e-01
# 13  Compass 4.27e+02 1.37e+02 2.36e-05     4.47e-07 5.00e+01 1.50e-01
# 14  Compass 2.26e+02 7.27e+01 8.39e-05     2.11e-07 1.00e+02 1.50e-01
# 15  Compass 2.13e+02 6.85e+01 9.44e-05     5.59e-08 2.00e+02 1.50e-01
# 16  Compass 2.21e+02 7.09e+01 9.99e-05     2.99e-04 2.86e+00 1.70e-01
# 17  Compass 2.20e+02 7.08e+01 1.00e-04     1.01e-03 1.56e+00 1.70e-01
# 18  Compass 2.45e+02 7.87e+01 9.53e-07     1.01e-03 1.60e-01 2.00e-03
#
#         B_0  CFL_diff  epsilon_D
# 3  4.00e-01  5.26e-03   8.47e-05
# 4  8.00e-01  3.72e-03   1.69e-04
# 11 6.60e-02  2.31e+00   7.69e-06
# 12 8.00e-01  1.63e-02   1.13e-03
# 13 8.00e-01  2.88e-03   1.13e-03
# 14 6.00e-01  3.82e-04   6.36e-04
# 15 8.00e-01  9.00e-05   1.13e-03
# 16 9.90e-02  5.16e-01   1.53e-05
# 17 7.30e-02  1.73e+00   8.30e-06
# 18 2.60e-02  2.15e+00   8.95e-05

# %%
physical={"name" : "Compass", "beta" : 1e-5, "resistivity": 1e-4, "tau" : 1,
    "m_i" : fp.deuteron_mass, "R_0" : 200, "R": 0.545,
    "a": 0.175, "q":2, "scaleR" : 1.3, "Nz" : 32}
fp.numerical2physical( physical, physical)
table = dict()
for s in show :
    table[s] = fp.parameters2quantity( physical, s)
    #print( s, "\t\t", physical[s])
df = pd.DataFrame.from_dict(table, orient="index")
df
# Out:
# Invert for given R
# /home/matthias/Projekte/utilities_feltor/feltorutilities.py:83: RuntimeWarning: invalid value encountered in double_scalars
#   cte.epsilon_0**2 * n_0*1e19 / B_0 / (T_e*cte.eV)**(3/2)
# /home/matthias/Projekte/utilities_feltor/feltorutilities.py:36: RuntimeWarning: invalid value encountered in sqrt
#   return  np.sqrt( T_e *cte.eV * m_i)  / cte.e / B_0
#                    0
# name         Compass
# R_0              200
# a_0         6.42e+01
# beta        1.00e-05
# resistivity 1.00e-04
# T_e         1.49e+00
# n_0         1.40e-02
# B_0         6.47e-02
# CFL_diff    1.41e-01
# epsilon_D   7.94e-05

# %%
physical={"name" : "Compass",
          "T_e" : 20, "T_i" :20, # T_e SOL = 10
          "m_i" : fp.deuteron_mass, "R": 0.545,
          "n_0" : 0.1, # 1e19
          "B_0" : .8, # 0.8 to 2.1
    "a":0.175, "q":2, "scaleR" : 1.3, "Nz" : 32}
for s in show :
    table[s] = fp.parameters2quantity( physical, s)
df = pd.DataFrame.from_dict(table, orient="index")
df
# Out:
#                    0
# name         Compass
# R_0         6.75e+02
# a_0         2.17e+02
# beta        6.29e-06
# resistivity 1.18e-06
# T_e               20
# n_0         1.00e-01
# B_0         8.00e-01
# CFL_diff    1.90e-02
# epsilon_D   1.69e-03

# %%
physical={"name" : "Torpex-ENRX",
    "T_e":2.21, "T_i": 0, "m_i" : fp.proton_mass,
    "R": 1, "n_0" : 0.001, "B_0" : 0.076, "a" : 0.2, "q":5,
    "scaleR" : 1.3, "Nz" : 32}
for s in show :
    table[s] = fp.parameters2quantity( physical, s)
df = pd.DataFrame.from_dict(table, orient="index")
df
# Out:
#                        0
# name         Torpex-ENRX
# R_0             5.00e+02
# a_0             1.00e+02
# beta            7.70e-07
# resistivity     3.38e-06
# T_e             2.21e+00
# n_0             1.00e-03
# B_0             7.60e-02
# CFL_diff        4.82e-02
# epsilon_D       3.06e-03
